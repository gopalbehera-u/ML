# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv(r'C:\Users\beher\OneDrive\Desktop\ML\datasets\placement.csv')

# %%
dataset.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
dataset.shape
# Out:
# (200, 2)

# %%
plt.scatter(dataset['cgpa'],dataset['package'])
plt.xlabel('CGPA')
plt.ylabel('package(in lpa)')
# Out:
# Text(0, 0.5, 'package(in lpa)')

# %%
x=dataset.iloc[:,0:1]
y=dataset.iloc[:,-1]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(dataset['cgpa'],dataset['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
lr_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print("MAE",mean_absolute_error(y_test,lr_pred))
# Out:
# MAE 0.2552433448620408

# %%
print("MSE",mean_squared_error(y_test,lr_pred))
# Out:
# MSE 0.10221131059334207

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,lr_pred)))
# Out:
# RMSE 0.31970503685951224

# %%
r2score=r2_score(y_test,lr_pred)
print("R2 SCORE ",r2score)
# Out:
# R2 SCORE  0.7297167943957027

# %%
# Adjusted R2 score 
x_test.shape
# Out:
# (40, 1)

# %%
1-((1-r2score)*(40-1)/(40-1-1))
# Out:
# 0.7226040784587475
